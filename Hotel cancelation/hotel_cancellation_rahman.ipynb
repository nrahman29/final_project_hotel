# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df1 = pd.read_csv('train.csv')
df2 = pd.read_csv('test.csv')

# %%
df2.head()
# Out:
#           hotel   lead_time  arrival_date_year arrival_date_month  \
# 0    City Hotel   26.298895                 30               July
# 1  Resort Hotel   92.577726                 40          September
# 2    City Hotel  227.333980                 38          September
# 3    City Hotel   60.329037                 28               July
# 4    City Hotel   89.803416                 25               June
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                      2016                         19
# 1                      2016                         27
# 2                      2015                         18
# 3                      2016                          7
# 4                      2016                         12
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                 0.420785              3.999927       3       0.0  ...
# 1                -0.747042              0.102923       1       0.0  ...
# 2                -0.454248              3.911471       2       0.0  ...
# 3                -0.403903              2.109956       2       0.0  ...
# 4                 2.490176              3.129876       2       0.0  ...
#
#    total_of_special_requests reservation_status reservation_status_date  \
# 0                          1           Canceled              2016-07-04
# 1                          0          Check-Out              2016-09-28
# 2                          0           Canceled              2015-03-25
# 3                          2          Check-Out              2016-07-09
# 4                          0           Canceled              2016-01-11
#
#              name                       email  phone-number       credit_card  \
# 0  Samantha Adams       SAdams@protonmail.com  762-421-5019  ************8511
# 1   Keith Hoffman     Hoffman_Keith@yahoo.com  893-041-9439  ************7474
# 2     Frank Terry           Frank.T91@att.com  963-035-5483  ************9831
# 3  Thomas Stevens  Thomas_Stevens64@gmail.com  145-450-3265  ************1211
# 4   Tiffany Rojas          Tiffany.R@mail.com  367-892-4321  ************3254
#
#       id estimated_check_in_duration booking_difficulty_score
# 0  54530                   17.041274                 3.019465
# 1  21700                   41.610677                -1.607991
# 2  74790                  109.138554                 1.928529
# 3  92567                   35.606458                 0.478480
# 4  52846                   50.549688                 1.658147
#
# [5 rows x 38 columns]

# %%
## Swapping incorrect year and week columns
col_list = list(df1)
col_list[3], col_list[5] = col_list[5], col_list[3]
df1.columns = col_list

col_list = list(df2)
col_list[2], col_list[4] = col_list[4], col_list[2]
df2.columns = col_list

# %%
#removing L room types which are low in numbers and does not exist in the test dataset
df1 = df1[df1.assigned_room_type != 'L']

# %%
df1.head()
# Out:
#           hotel  is_canceled   lead_time  arrival_date_week_number  \
# 0  Resort Hotel            0         NaN                         9
# 1    City Hotel            0   82.916916                        11
# 2    City Hotel            0   24.534646                        44
# 3    City Hotel            1  169.265992                        12
# 4    City Hotel            0  -22.240921                         3
#
#   arrival_date_month  arrival_date_year  arrival_date_day_of_month  \
# 0              March               2017                          2
# 1              March               2017                         15
# 2            October               2016                         23
# 3              March               2017                         23
# 4          Veganuary               2017                         19
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                 0.820075              2.546977       1  ...
# 1                -0.325630              2.002309       2  ...
# 2                 1.820523              1.289780       1  ...
# 3                 0.721699              1.848563       2  ...
# 4                -0.097702              1.045354       2  ...
#
#    total_of_special_requests  reservation_status reservation_status_date  \
# 0                          0           Check-Out              2017-03-06
# 1                          2           Check-Out              2017-03-16
# 2                          1           Check-Out              2016-10-25
# 3                          2            Canceled              2017-01-19
# 4                          1            Canceled              2016-10-26
#
#               name                          email  phone-number  \
# 0     Edward Davis                EDavis@mail.com  129-327-5067
# 1  Joshua Sullivan             JSullivan@zoho.com  748-584-5256
# 2   Zachary Bishop       Bishop_Zachary@gmail.com  880-124-3628
# 3    Victoria Kent          Victoria.Kent@aol.com  814-180-1532
# 4  Michael Johnson  Johnson_Michael11@xfinity.com  118-263-8905
#
#         credit_card      id  estimated_check_in_duration  \
# 0  ************1227   33852                          NaN
# 1  ************7930   97750                    47.282901
# 2  ************2924  100248                    13.811002
# 3  ************7923   65077                    81.319112
# 4  ************9630   62714                    -9.889995
#
#   booking_difficulty_score
# 0                      NaN
# 1                -3.218666
# 2                 3.859197
# 3                 1.510322
# 4                 4.345359
#
# [5 rows x 39 columns]

# %%
df2.head()
# Out:
#           hotel   lead_time  arrival_date_week_number arrival_date_month  \
# 0    City Hotel   26.298895                        30               July
# 1  Resort Hotel   92.577726                        40          September
# 2    City Hotel  227.333980                        38          September
# 3    City Hotel   60.329037                        28               July
# 4    City Hotel   89.803416                        25               June
#
#    arrival_date_year  arrival_date_day_of_month  stays_in_weekend_nights  \
# 0               2016                         19                 0.420785
# 1               2016                         27                -0.747042
# 2               2015                         18                -0.454248
# 3               2016                          7                -0.403903
# 4               2016                         12                 2.490176
#
#    stays_in_week_nights  adults  children  ...  total_of_special_requests  \
# 0              3.999927       3       0.0  ...                          1
# 1              0.102923       1       0.0  ...                          0
# 2              3.911471       2       0.0  ...                          0
# 3              2.109956       2       0.0  ...                          2
# 4              3.129876       2       0.0  ...                          0
#
#   reservation_status reservation_status_date            name  \
# 0           Canceled              2016-07-04  Samantha Adams
# 1          Check-Out              2016-09-28   Keith Hoffman
# 2           Canceled              2015-03-25     Frank Terry
# 3          Check-Out              2016-07-09  Thomas Stevens
# 4           Canceled              2016-01-11   Tiffany Rojas
#
#                         email  phone-number       credit_card     id  \
# 0       SAdams@protonmail.com  762-421-5019  ************8511  54530
# 1     Hoffman_Keith@yahoo.com  893-041-9439  ************7474  21700
# 2           Frank.T91@att.com  963-035-5483  ************9831  74790
# 3  Thomas_Stevens64@gmail.com  145-450-3265  ************1211  92567
# 4          Tiffany.R@mail.com  367-892-4321  ************3254  52846
#
#   estimated_check_in_duration booking_difficulty_score
# 0                   17.041274                 3.019465
# 1                   41.610677                -1.607991
# 2                  109.138554                 1.928529
# 3                   35.606458                 0.478480
# 4                   50.549688                 1.658147
#
# [5 rows x 38 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83572 entries, 0 to 83572
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           83572 non-null  object
#  1   is_canceled                     83572 non-null  int64
#  2   lead_time                       79289 non-null  float64
#  3   arrival_date_week_number        83572 non-null  int64
#  4   arrival_date_month              83572 non-null  object
#  5   arrival_date_year               83572 non-null  int64
#  6   arrival_date_day_of_month       83572 non-null  int64
#  7   stays_in_weekend_nights         83572 non-null  float64
#  8   stays_in_week_nights            83572 non-null  float64
#  9   adults                          83572 non-null  int64
#  10  children                        83570 non-null  float64
#  11  babies                          83572 non-null  int64
#  12  meal                            79289 non-null  object
#  13  country                         79032 non-null  object
#  14  market_segment                  83572 non-null  object
#  15  distribution_channel            83572 non-null  object
#  16  is_repeated_guest               83572 non-null  int64
#  17  previous_cancellations          83572 non-null  int64
#  18  previous_bookings_not_canceled  83572 non-null  int64
#  19  reserved_room_type              83572 non-null  object
#  20  assigned_room_type              83572 non-null  object
#  21  booking_changes                 83572 non-null  int64
#  22  deposit_type                    83572 non-null  object
#  23  agent                           72224 non-null  float64
#  24  company                         4674 non-null   float64
#  25  days_in_waiting_list            83572 non-null  float64
#  26  customer_type                   83572 non-null  object
#  27  adr                             79289 non-null  float64
#  28  required_car_parking_spaces     83572 non-null  int64
#  29  total_of_special_requests       83572 non-null  int64
#  30  reservation_status              83572 non-null  object
#  31  reservation_status_date         83572 non-null  object
#  32  name                            83572 non-null  object
#  33  email                           83572 non-null  object
#  34  phone-number                    83572 non-null  object
#  35  credit_card                     83572 non-null  object
#  36  id                              83572 non-null  int64
#  37  estimated_check_in_duration     79289 non-null  float64
#  38  booking_difficulty_score        79289 non-null  float64
# dtypes: float64(10), int64(13), object(16)
# memory usage: 25.5+ MB

# %%
df1.describe()
# Out:
#         is_canceled     lead_time  arrival_date_week_number  \
# count  83572.000000  79289.000000              83572.000000
# mean       0.397202    103.378985                 27.120303
# std        0.489321    119.377243                 13.619749
# min        0.000000   -227.156938                  1.000000
# 25%        0.000000     18.368606                 16.000000
# 50%        0.000000     79.567092                 27.000000
# 75%        1.000000    167.572929                 38.000000
# max        1.000000    741.651834                 53.000000
#
#        arrival_date_year  arrival_date_day_of_month  stays_in_weekend_nights  \
# count       83572.000000               83572.000000             83572.000000
# mean         2016.155925                  15.788063                 0.928773
# std             0.707374                   8.782540                 1.118729
# min          2015.000000                   1.000000                -1.791310
# 25%          2016.000000                   8.000000                 0.065456
# 50%          2016.000000                  16.000000                 0.795766
# 75%          2017.000000                  23.000000                 1.713248
# max          2017.000000                  31.000000                19.232182
#
#        stays_in_week_nights        adults     children        babies  ...  \
# count          83572.000000  83572.000000  83570.00000  83572.000000  ...
# mean               2.492890      1.859223      0.10292      0.008137  ...
# std                2.126714      0.594784      0.39728      0.096017  ...
# min               -3.794357      0.000000      0.00000      0.000000  ...
# 25%                1.105951      2.000000      0.00000      0.000000  ...
# 50%                2.217651      2.000000      0.00000      0.000000  ...
# 75%                3.551790      2.000000      0.00000      0.000000  ...
# max               49.354003     55.000000     10.00000      9.000000  ...
#
#        booking_changes         agent      company  days_in_waiting_list  \
# count     83572.000000  72224.000000  4674.000000          83572.000000
# mean          0.220684     86.603774   186.998074              2.321636
# std           0.654789    110.672677   130.511313             19.326472
# min           0.000000      1.000000     9.000000            -36.442446
# 25%           0.000000      9.000000    59.000000             -5.701492
# 50%           0.000000     14.000000   174.000000              0.394768
# 75%           0.000000    229.000000   268.000000              6.589788
# max          20.000000    535.000000   543.000000            401.792112
#
#                 adr  required_car_parking_spaces  total_of_special_requests  \
# count  79289.000000                 83572.000000               83572.000000
# mean     101.734898                     0.061791                   0.572752
# std       57.456664                     0.243446                   0.794275
# min      -80.136040                     0.000000                   0.000000
# 25%       65.608619                     0.000000                   0.000000
# 50%       96.152179                     0.000000                   0.000000
# 75%      131.647921                     0.000000                   1.000000
# max     5411.546686                     8.000000                   5.000000
#
#                   id  estimated_check_in_duration  booking_difficulty_score
# count   83572.000000                 79289.000000              79289.000000
# mean    59698.911226                    51.673498                  1.293792
# std     34498.702055                    60.534993                  2.294591
# min         1.000000                  -123.491940                 -5.127325
# 25%     29788.750000                     8.511831                  0.102999
# 50%     59782.500000                    40.425592                  1.090571
# 75%     89525.250000                    84.542614                  2.131484
# max    119390.000000                   370.155876                 55.593803
#
# [8 rows x 23 columns]

# %%
df1.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                          4283
# arrival_date_week_number              0
# arrival_date_month                    0
# arrival_date_year                     0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              2
# babies                                0
# meal                               4283
# country                            4540
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# agent                             11348
# company                           78898
# days_in_waiting_list                  0
# customer_type                         0
# adr                                4283
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# reservation_status_date               0
# name                                  0
# email                                 0
# phone-number                          0
# credit_card                           0
# id                                    0
# estimated_check_in_duration        4283
# booking_difficulty_score           4283
# dtype: int64

# %%
#creating a function to preprocess the testing and training datasets.
def preprocessing(dataframe):

    # Converting typo 'Veganuary' to 'January'
    dataframe['arrival_date_month'] = dataframe['arrival_date_month'].str.replace('Veganuary', 'January')

    # Converting negative values to positive and rounding them
    for col in ['lead_time', 'days_in_waiting_list', 'adr', 'estimated_check_in_duration', 
                'booking_difficulty_score', 'stays_in_weekend_nights', 'stays_in_week_nights']:
        dataframe[col] = dataframe[col].abs().round()

    # filling missing rows with average and filling missing children with 0
    ####dataframe.dropna(subset=['lead_time'], axis=0, inplace=True)
    columnsWithNa = ['lead_time', 'estimated_check_in_duration', 'adr', 'booking_difficulty_score' ]
    for column in columnsWithNa :
        dataframe[column] = dataframe[column].fillna(dataframe[column].mean())

    dataframe['children'] = dataframe['children'].fillna(value=0)

    # Creating new features for private booking and booking without agent
    dataframe.loc[~dataframe['company'].isnull(), 'private_booking'] = 0
    dataframe['private_booking'] = dataframe['private_booking'].fillna(1)
    
    dataframe.loc[~dataframe['agent'].isnull(), 'booking_without_agent'] = 0
    dataframe['booking_without_agent'] = dataframe['booking_without_agent'].fillna(1)

    # Changing unavailable entries to 'N/A'
    for col in ['market_segment', 'distribution_channel']:
        dataframe.loc[dataframe[col].isin(['UNAVAILABLE', 'MISSING', 'UNKNOWN', 'Undefined']), col] = 'N/A'

    # Dropping unnecessary columns
    dataframe.drop(['agent', 'company', 'name', 'email', 'phone-number', 'credit_card', 'meal', 'country'], axis=1, inplace=True)

    # Handling reservation status date and creating date_delta
    dataframe['reservation_status_date'] = pd.to_datetime(dataframe['reservation_status_date'], errors='coerce')
    dataframe['date_delta'] = (dataframe['reservation_status_date'] - dataframe['reservation_status_date'].min()) / np.timedelta64(1, 'D')
    dataframe.drop('reservation_status_date', axis=1, inplace=True)

    # # # One-hot encoding categorical columns
    # dataframe = pd.get_dummies(dataframe, columns=["hotel", "arrival_date_month", 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'reservation_status'])

    return dataframe

# %%
preprocessing(df1)
# for some reason onehot encoding was not working in the function
df1 = pd.get_dummies(df1, columns=["hotel", "arrival_date_month", 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'reservation_status'],drop_first=True)
# Out:
# C:\Users\nvd_u\AppData\Local\Temp\ipykernel_3352\496586125.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe['booking_without_agent'] = dataframe['booking_without_agent'].fillna(1, inplace=True)

# %%
preprocessing(df2)
df2 = pd.get_dummies(df2, columns=["hotel", "arrival_date_month", 'market_segment', 'distribution_channel', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'reservation_status'],drop_first=True)
# Out:
# C:\Users\nvd_u\AppData\Local\Temp\ipykernel_3352\496586125.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe['booking_without_agent'] = dataframe['booking_without_agent'].fillna(1, inplace=True)

# %%
df2.head()
# Out:
#    lead_time  arrival_date_week_number  arrival_date_year  \
# 0       26.0                        30               2016
# 1       93.0                        40               2016
# 2      227.0                        38               2015
# 3       60.0                        28               2016
# 4       90.0                        25               2016
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                         19                      0.0                   4.0
# 1                         27                      1.0                   0.0
# 2                         18                      0.0                   4.0
# 3                          7                      0.0                   2.0
# 4                         12                      2.0                   3.0
#
#    adults  children  babies  is_repeated_guest  ...  assigned_room_type_I  \
# 0       3       0.0       0                  0  ...                 False
# 1       1       0.0       0                  1  ...                 False
# 2       2       0.0       0                  0  ...                 False
# 3       2       0.0       0                  0  ...                 False
# 4       2       0.0       0                  0  ...                 False
#
#    assigned_room_type_K  assigned_room_type_P  deposit_type_Non Refund  \
# 0                 False                 False                    False
# 1                 False                 False                    False
# 2                 False                 False                     True
# 3                 False                 False                    False
# 4                 False                 False                    False
#
#    deposit_type_Refundable  customer_type_Group  customer_type_Transient  \
# 0                    False                False                     True
# 1                    False                False                     True
# 2                    False                False                    False
# 3                    False                False                     True
# 4                    False                False                    False
#
#    customer_type_Transient-Party  reservation_status_Check-Out  \
# 0                          False                         False
# 1                          False                          True
# 2                           True                         False
# 3                          False                          True
# 4                           True                         False
#
#    reservation_status_No-Show
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
# [5 rows x 72 columns]

# %%
# import plotly.express as px

# for col in df1.columns:
#     plt = px.histogram(df1, x = col, color ="is_canceled", title=col + ' vs is_canceled')
#     plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# #specify size of heatmap
# fig, ax = plt.subplots(figsize=(30, 30))

# #create seaborn heatmap
# sns.heatmap(df1.corr(), annot=True, cmap='coolwarm')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83572 entries, 0 to 83572
# Data columns (total 73 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   is_canceled                     83572 non-null  int64
#  1   lead_time                       83572 non-null  float64
#  2   arrival_date_week_number        83572 non-null  int64
#  3   arrival_date_year               83572 non-null  int64
#  4   arrival_date_day_of_month       83572 non-null  int64
#  5   stays_in_weekend_nights         83572 non-null  float64
#  6   stays_in_week_nights            83572 non-null  float64
#  7   adults                          83572 non-null  int64
#  8   children                        83572 non-null  float64
#  9   babies                          83572 non-null  int64
#  10  is_repeated_guest               83572 non-null  int64
#  11  previous_cancellations          83572 non-null  int64
#  12  previous_bookings_not_canceled  83572 non-null  int64
#  13  booking_changes                 83572 non-null  int64
#  14  days_in_waiting_list            83572 non-null  float64
#  15  adr                             83572 non-null  float64
#  16  required_car_parking_spaces     83572 non-null  int64
#  17  total_of_special_requests       83572 non-null  int64
#  18  id                              83572 non-null  int64
#  19  estimated_check_in_duration     83572 non-null  float64
#  20  booking_difficulty_score        83572 non-null  float64
#  21  private_booking                 83572 non-null  float64
#  22  booking_without_agent           0 non-null      object
#  23  date_delta                      83572 non-null  float64
#  24  hotel_Resort Hotel              83572 non-null  bool
#  25  arrival_date_month_August       83572 non-null  bool
#  26  arrival_date_month_December     83572 non-null  bool
#  27  arrival_date_month_February     83572 non-null  bool
#  28  arrival_date_month_January      83572 non-null  bool
#  29  arrival_date_month_July         83572 non-null  bool
#  30  arrival_date_month_June         83572 non-null  bool
#  31  arrival_date_month_March        83572 non-null  bool
#  32  arrival_date_month_May          83572 non-null  bool
#  33  arrival_date_month_November     83572 non-null  bool
#  34  arrival_date_month_October      83572 non-null  bool
#  35  arrival_date_month_September    83572 non-null  bool
#  36  market_segment_Complementary    83572 non-null  bool
#  37  market_segment_Corporate        83572 non-null  bool
#  38  market_segment_Direct           83572 non-null  bool
#  39  market_segment_Groups           83572 non-null  bool
#  40  market_segment_N/A              83572 non-null  bool
#  41  market_segment_Offline TA/TO    83572 non-null  bool
#  42  market_segment_Online TA        83572 non-null  bool
#  43  distribution_channel_Direct     83572 non-null  bool
#  44  distribution_channel_GDS        83572 non-null  bool
#  45  distribution_channel_N/A        83572 non-null  bool
#  46  distribution_channel_TA/TO      83572 non-null  bool
#  47  reserved_room_type_B            83572 non-null  bool
#  48  reserved_room_type_C            83572 non-null  bool
#  49  reserved_room_type_D            83572 non-null  bool
#  50  reserved_room_type_E            83572 non-null  bool
#  51  reserved_room_type_F            83572 non-null  bool
#  52  reserved_room_type_G            83572 non-null  bool
#  53  reserved_room_type_H            83572 non-null  bool
#  54  reserved_room_type_L            83572 non-null  bool
#  55  reserved_room_type_P            83572 non-null  bool
#  56  assigned_room_type_B            83572 non-null  bool
#  57  assigned_room_type_C            83572 non-null  bool
#  58  assigned_room_type_D            83572 non-null  bool
#  59  assigned_room_type_E            83572 non-null  bool
#  60  assigned_room_type_F            83572 non-null  bool
#  61  assigned_room_type_G            83572 non-null  bool
#  62  assigned_room_type_H            83572 non-null  bool
#  63  assigned_room_type_I            83572 non-null  bool
#  64  assigned_room_type_K            83572 non-null  bool
#  65  assigned_room_type_P            83572 non-null  bool
#  66  deposit_type_Non Refund         83572 non-null  bool
#  67  deposit_type_Refundable         83572 non-null  bool
#  68  customer_type_Group             83572 non-null  bool
#  69  customer_type_Transient         83572 non-null  bool
#  70  customer_type_Transient-Party   83572 non-null  bool
#  71  reservation_status_Check-Out    83572 non-null  bool
#  72  reservation_status_No-Show      83572 non-null  bool
# dtypes: bool(49), float64(10), int64(13), object(1)
# memory usage: 19.8+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35817 entries, 0 to 35816
# Data columns (total 72 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   lead_time                       35817 non-null  float64
#  1   arrival_date_week_number        35817 non-null  int64
#  2   arrival_date_year               35817 non-null  int64
#  3   arrival_date_day_of_month       35817 non-null  int64
#  4   stays_in_weekend_nights         35817 non-null  float64
#  5   stays_in_week_nights            35817 non-null  float64
#  6   adults                          35817 non-null  int64
#  7   children                        35817 non-null  float64
#  8   babies                          35817 non-null  int64
#  9   is_repeated_guest               35817 non-null  int64
#  10  previous_cancellations          35817 non-null  int64
#  11  previous_bookings_not_canceled  35817 non-null  int64
#  12  booking_changes                 35817 non-null  int64
#  13  days_in_waiting_list            35817 non-null  float64
#  14  adr                             35817 non-null  float64
#  15  required_car_parking_spaces     35817 non-null  int64
#  16  total_of_special_requests       35817 non-null  int64
#  17  id                              35817 non-null  int64
#  18  estimated_check_in_duration     35817 non-null  float64
#  19  booking_difficulty_score        35817 non-null  float64
#  20  private_booking                 35817 non-null  float64
#  21  booking_without_agent           0 non-null      object
#  22  date_delta                      35817 non-null  float64
#  23  hotel_Resort Hotel              35817 non-null  bool
#  24  arrival_date_month_August       35817 non-null  bool
#  25  arrival_date_month_December     35817 non-null  bool
#  26  arrival_date_month_February     35817 non-null  bool
#  27  arrival_date_month_January      35817 non-null  bool
#  28  arrival_date_month_July         35817 non-null  bool
#  29  arrival_date_month_June         35817 non-null  bool
#  30  arrival_date_month_March        35817 non-null  bool
#  31  arrival_date_month_May          35817 non-null  bool
#  32  arrival_date_month_November     35817 non-null  bool
#  33  arrival_date_month_October      35817 non-null  bool
#  34  arrival_date_month_September    35817 non-null  bool
#  35  market_segment_Complementary    35817 non-null  bool
#  36  market_segment_Corporate        35817 non-null  bool
#  37  market_segment_Direct           35817 non-null  bool
#  38  market_segment_Groups           35817 non-null  bool
#  39  market_segment_N/A              35817 non-null  bool
#  40  market_segment_Offline TA/TO    35817 non-null  bool
#  41  market_segment_Online TA        35817 non-null  bool
#  42  distribution_channel_Direct     35817 non-null  bool
#  43  distribution_channel_GDS        35817 non-null  bool
#  44  distribution_channel_N/A        35817 non-null  bool
#  45  distribution_channel_TA/TO      35817 non-null  bool
#  46  reserved_room_type_B            35817 non-null  bool
#  47  reserved_room_type_C            35817 non-null  bool
#  48  reserved_room_type_D            35817 non-null  bool
#  49  reserved_room_type_E            35817 non-null  bool
#  50  reserved_room_type_F            35817 non-null  bool
#  51  reserved_room_type_G            35817 non-null  bool
#  52  reserved_room_type_H            35817 non-null  bool
#  53  reserved_room_type_L            35817 non-null  bool
#  54  reserved_room_type_P            35817 non-null  bool
#  55  assigned_room_type_B            35817 non-null  bool
#  56  assigned_room_type_C            35817 non-null  bool
#  57  assigned_room_type_D            35817 non-null  bool
#  58  assigned_room_type_E            35817 non-null  bool
#  59  assigned_room_type_F            35817 non-null  bool
#  60  assigned_room_type_G            35817 non-null  bool
#  61  assigned_room_type_H            35817 non-null  bool
#  62  assigned_room_type_I            35817 non-null  bool
#  63  assigned_room_type_K            35817 non-null  bool
#  64  assigned_room_type_P            35817 non-null  bool
#  65  deposit_type_Non Refund         35817 non-null  bool
#  66  deposit_type_Refundable         35817 non-null  bool
#  67  customer_type_Group             35817 non-null  bool
#  68  customer_type_Transient         35817 non-null  bool
#  69  customer_type_Transient-Party   35817 non-null  bool
#  70  reservation_status_Check-Out    35817 non-null  bool
#  71  reservation_status_No-Show      35817 non-null  bool
# dtypes: bool(49), float64(10), int64(12), object(1)
# memory usage: 8.0+ MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, r2_score


X = df1.drop('is_canceled', axis=1) 
y = df1['is_canceled']           
X_train, X_test, y_train, y_test = train_test_split(df1.drop('is_canceled',axis=1), 
           df1['is_canceled'], test_size=0.30, 
            random_state=42)



logmodel = RandomForestClassifier()
result = logmodel.fit(X_train, y_train)

# %%
from sklearn.metrics import accuracy_score
y_pred = logmodel.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%') #Check accuracy of model
# Out:
# Accuracy: 89.82%

# %%
df2['is_canceled'] = logmodel.predict(df2)

# %%
df3 = df2.loc[:, ["id", "is_canceled"]]

# %%
df3.head()
# Out:
#       id  is_canceled
# 0  54530            1
# 1  21700            0
# 2  74790            1
# 3  92567            0
# 4  52846            1

# %%
df3.to_csv('output_2.csv', sep=',', index=False)
